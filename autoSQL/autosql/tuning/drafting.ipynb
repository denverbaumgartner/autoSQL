# %%
print('hello, world!')
# Out:
# hello, world!

# %%
import re

with open("training_logs.txt", "r") as f:
    text = f.read()

def parse_training_info(text):
    lines = text.split("\n")
    parsed_data = {}
    current_epoch = None

    for line in lines:
        # Extract epoch start
        epoch_match = re.search(r'Training Epoch(\d+):', line)
        if epoch_match:
            current_epoch = int(epoch_match.group(1))
            if current_epoch not in parsed_data:
                parsed_data[current_epoch] = {"steps": {}}
            continue

        # Extract loss after each step, associate with current epoch
        step_loss_match = re.search(r'step (\d+) is completed and loss is (\d+\.\d+)', line)
        if step_loss_match and current_epoch is not None:
            step = int(step_loss_match.group(1))
            loss = float(step_loss_match.group(2))
            parsed_data[current_epoch]["steps"][step] = loss
            continue

        # Extract evaluation info and associate with current epoch
        eval_ppl_match = re.search(r'eval_ppl=tensor\((\d+\.\d+), device=\'cuda:0\'\)', line)
        eval_epoch_loss_match = re.search(r'eval_epoch_loss=tensor\((\d+\.\d+), device=\'cuda:0\'\)', line)
        if eval_ppl_match and eval_epoch_loss_match and current_epoch is not None:
            parsed_data[current_epoch]["eval_ppl"] = float(eval_ppl_match.group(1))
            parsed_data[current_epoch]["eval_epoch_loss"] = float(eval_epoch_loss_match.group(1))

    return parsed_data

parsed_data = parse_training_info(text)
for epoch, data in parsed_data.items():
    print(f"Epoch {epoch}:")
    for key, value in data.items():
        print(f"  {key}: {value}")
# Out:
# Epoch 0:
# ...

# %%
# Out:
# {}

# %%
from pyngrok import ngrok

# %%
# Close all open tunnels
ngrok.kill()

# %%
public_url = ngrok.connect(3000)
# Out:
# t=2023-09-26T17:45:20-0400 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path="/Users/denver/Library/Application Support/ngrok/ngrok.yml" legacy_path=/Users/denver/.ngrok2/ngrok.yml

# %%
type(public_url.public_url)
# Out:
# str

# %%
import requests
import json

def create_gist(token, filename, content, description="", is_public=True):
    """
    Create a gist on GitHub.

    Args:
    - token (str): GitHub personal access token
    - filename (str): Name of the file to be created in the gist
    - content (str): Content of the file
    - description (str, optional): Description for the gist
    - is_public (bool, optional): Whether the gist should be public

    Returns:
    - dict: Response from the GitHub API
    """
    
    # Define the URL for creating gists
    url = "https://api.github.com/gists"

    # Define the headers for the request
    headers = {
        "Authorization": f"token {token}",
        "Content-Type": "application/jsonl",
    }

    # Define the data for the gist
    data = {
        "description": description,
        "public": is_public,
        "files": {
            filename: {
                "content": content
            }
        }
    }

    # Make the POST request
    response = requests.post(url, headers=headers, data=json.dumps(data))
    
    # Return the response as a dictionary
    return response.json()

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv("../../.env")

# Now you can get the loaded environment variable using os.environ
GITHUB_GIST_TOKEN = os.environ.get("GITHUB_GIST_TOKEN")

# %%
print(GITHUB_GIST_TOKEN)
# Out:
# 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

# %%
# Usage
gh_token = GITHUB_GIST_TOKEN
filename = "example.jsonl"
content = "{This is the content of the gist file.}"

response = create_gist(gh_token, filename, content, description="A test gist", is_public=True)
print(response)

# {'url': 'https://api.github.com/gists/dc828136c9254cdb30eebec6385a0328', 'forks_url': 'https://api.github.com/gists/dc828136c9254cdb30eebec6385a0328/forks', 'commits_url': 'https://api.github.com/gists/dc828136c9254cdb30eebec6385a0328/commits', 'id': 'dc828136c9254cdb30eebec6385a0328', 'node_id': 'G_kwDOA6hVldoAIGRjODI4MTM2YzkyNTRjZGIzMGVlYmVjNjM4NWEwMzI4', 'git_pull_url': 'https://gist.github.com/dc828136c9254cdb30eebec6385a0328.git', 'git_push_url': 'https://gist.github.com/dc828136c9254cdb30eebec6385a0328.git', 'html_url': 'https://gist.github.com/denverbaumgartner/dc828136c9254cdb30eebec6385a0328', 'files': {'example.txt': {'filename': 'example.txt', 'type': 'text/plain', 'language': 'Text', 'raw_url': 'https://gist.githubusercontent.com/denverbaumgartner/dc828136c9254cdb30eebec6385a0328/raw/6dbc691142754d7552906261423ab12f931b5d64/example.txt', 'size': 37, 'truncated': False, 'content': 'This is the content of the gist file.'}}, 'public': True, 'created_at': '2023-09-26T17:54:49Z', 'updated_at': '2023-09-26T17:54:49Z', 'description': 'A test gist', 'comments': 0, 'user': None, 'comments_url': 'https://api.github.com/gists/dc828136c9254cdb30eebec6385a0328/comments', 'owner': {'login': 'denverbaumgartner', 'id': 61363605, 'node_id': 'MDQ6VXNlcjYxMzYzNjA1', 'avatar_url': 'https://avatars.githubusercontent.com/u/61363605?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/denverbaumgartner', 'html_url': 'https://github.com/denverbaumgartner', 'followers_url': 'https://api.github.com/users/denverbaumgartner/followers', 'following_url': 'https://api.github.com/users/denverbaumgartner/following{/other_user}', 'gists_url': 'https://api.github.com/users/denverbaumgartner/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/denverbaumgartner/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/denverbaumgartner/subscriptions', 'organizations_url': 'https://api.github.com/users/denverbaumgartner/orgs', 'repos_url': 'https://api.github.com/users/denverbaumgartner/repos', 'events_url': 'https://api.github.com/users/denverbaumgartner/events{/privacy}', 'received_events_url': 'https://api.github.com/users/denverbaumgartner/received_events', 'type': 'User', 'site_admin': False}, 'forks': [], 'history': [{'user': {'login': 'denverbaumgartner', 'id': 61363605, 'node_id': 'MDQ6VXNlcjYxMzYzNjA1', 'avatar_url': 'https://avatars.githubusercontent.com/u/61363605?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/denverbaumgartner', 'html_url': 'https://github.com/denverbaumgartner', 'followers_url': 'https://api.github.com/users/denverbaumgartner/followers', 'following_url': 'https://api.github.com/users/denverbaumgartner/following{/other_user}', 'gists_url': 'https://api.github.com/users/denverbaumgartner/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/denverbaumgartner/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/denverbaumgartner/subscriptions', 'organizations_url': 'https://api.github.com/users/denverbaumgartner/orgs', 'repos_url': 'https://api.github.com/users/denverbaumgartner/repos', 'events_url': 'https://api.github.com/users/denverbaumgartner/events{/privacy}', 'received_events_url': 'https://api.github.com/users/denverbaumgartner/received_events', 'type': 'User', 'site_admin': False}, 'version': '94351fab518df73ac18d1e33a4eea1c9577cf1af', 'committed_at': '2023-09-26T17:54:49Z', 'change_status': {'total': 1, 'additions': 1, 'deletions': 0}, 'url': 'https://api.github.com/gists/dc828136c9254cdb30eebec6385a0328/94351fab518df73ac18d1e33a4eea1c9577cf1af'}], 'truncated': False}
# Out:
# {'url': 'https://api.github.com/gists/822ae88cb84a23da9bdec25b3ff1112e', 'forks_url': 'https://api.github.com/gists/822ae88cb84a23da9bdec25b3ff1112e/forks', 'commits_url': 'https://api.github.com/gists/822ae88cb84a23da9bdec25b3ff1112e/commits', 'id': '822ae88cb84a23da9bdec25b3ff1112e', 'node_id': 'G_kwDOA6hVldoAIDgyMmFlODhjYjg0YTIzZGE5YmRlYzI1YjNmZjExMTJl', 'git_pull_url': 'https://gist.github.com/822ae88cb84a23da9bdec25b3ff1112e.git', 'git_push_url': 'https://gist.github.com/822ae88cb84a23da9bdec25b3ff1112e.git', 'html_url': 'https://gist.github.com/denverbaumgartner/822ae88cb84a23da9bdec25b3ff1112e', 'files': {'example.txt': {'filename': 'example.txt', 'type': 'text/plain', 'language': 'Text', 'raw_url': 'https://gist.githubusercontent.com/denverbaumgartner/822ae88cb84a23da9bdec25b3ff1112e/raw/6dbc691142754d7552906261423ab12f931b5d64/example.txt', 'size': 37, 'truncated': False, 'content': 'This is the content of the gist file.'}}, 'public': True, 'created_at': '2023-09-26T17:58:19
# ...

# %%
response["files"][filename]['raw_url']
# Out:
# 'https://gist.githubusercontent.com/denverbaumgartner/822ae88cb84a23da9bdec25b3ff1112e/raw/6dbc691142754d7552906261423ab12f931b5d64/example.txt'

# %%
url = response["files"][filename]['raw_url']
response = requests.get(url)

# %%
response.text
# Out:
# 'This is the content of the gist file.'
